# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("bank_fraud.csv")

# %%
df.head()
# Out:
#   transaction_id   customer_id transaction_date transaction_time  hour_of_day  \
# 0  TXN0000000001  CUST00121959       2023-08-17         21:13:00           21
# 1  TXN0000000002  CUST00146868       2024-02-06         05:16:00            5
# 2  TXN0000000003  CUST00131933       2024-06-28         12:15:00           12
# 3  TXN0000000004  CUST00103695       2023-03-16         02:53:00            2
# 4  TXN0000000005  CUST00119880       2024-07-12         12:39:00           12
#
#    is_weekend  is_night_transaction country       city merchant_category  ...  \
# 0           0                     0     USA     London           Grocery  ...
# 1           0                     1      UK   New York        Healthcare  ...
# 2           0                     0  Canada      Delhi           Grocery  ...
# 3           0                     1  France      Tokyo         Utilities  ...
# 4           0                     0  Canada  Melbourne          Clothing  ...
#
#   transaction_amount num_prev_transactions  transaction_freq_monthly  \
# 0              39.49                   157                        23
# 1             153.71                   153                        23
# 2             118.20                   161                        20
# 3              49.50                   160                        25
# 4              30.74                   134                        18
#
#    distance_from_home_km  time_since_last_txn_hrs  is_international  \
# 0                   52.7                    10.20                 0
# 1                    0.9                    12.47                 0
# 2                    9.2                     0.08                 0
# 3                   14.8                    17.94                 1
# 4                   38.9                     2.16                 0
#
#    failed_attempts  pin_changed_recently  is_fraud          fraud_type
# 0                0                     0         0                 NaN
# 1                0                     0         0                 NaN
# 2                1                     0         0                 NaN
# 3                0                     1         1  Synthetic Identity
# 4                0                     0         0                 NaN
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#        transaction_id   customer_id transaction_date transaction_time  \
# 999995  TXN0000999996  CUST00176672       2022-11-18         21:15:00
# 999996  TXN0000999997  CUST00005742       2021-07-03         22:57:00
# 999997  TXN0000999998  CUST00108137       2021-08-12         07:37:00
# 999998  TXN0000999999  CUST00117141       2021-06-07         07:09:00
# 999999  TXN0001000000  CUST00117401       2021-01-07         18:43:00
#
#         hour_of_day  is_weekend  is_night_transaction country        city  \
# 999995           21           0                     0  Mexico        Lyon
# 999996           22           1                     1  Mexico       Tokyo
# 999997            7           0                     0     USA  Manchester
# 999998            7           0                     0   Japan   São Paulo
# 999999           18           0                     0   India      Berlin
#
#        merchant_category  ... transaction_amount num_prev_transactions  \
# 999995       Electronics  ...            1923.52                   145
# 999996   Online Shopping  ...             146.16                   154
# 999997           Grocery  ...              27.38                   148
# 999998       Electronics  ...             365.30                   150
# 999999   Crypto Exchange  ...              60.82                   154
#
#         transaction_freq_monthly  distance_from_home_km  \
# 999995                        20                   36.5
# 999996                        17                   20.0
# 999997                        20                    3.4
# 999998                        16                   63.1
# 999999                        15                   12.6
#
#         time_since_last_txn_hrs  is_international  failed_attempts  \
# 999995                     1.58                 0                0
# 999996                     2.10                 0                0
# 999997                     2.74                 0                1
# 999998                     3.71                 1                1
# 999999                    13.53                 1                0
#
#         pin_changed_recently  is_fraud  fraud_type
# 999995                     0         0         NaN
# 999996                     0         0         NaN
# 999997                     0         0         NaN
# 999998                     0         0         NaN
# 999999                     0         0         NaN
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   transaction_id            1000000 non-null  str
#  1   customer_id               1000000 non-null  str
#  2   transaction_date          1000000 non-null  str
#  3   transaction_time          1000000 non-null  str
#  4   hour_of_day               1000000 non-null  int64
#  5   is_weekend                1000000 non-null  int64
#  6   is_night_transaction      1000000 non-null  int64
#  7   country                   1000000 non-null  str
#  8   city                      1000000 non-null  str
#  9   merchant_category         1000000 non-null  str
#  10  payment_method            1000000 non-null  str
#  11  device_type               1000000 non-null  str
#  12  customer_age              1000000 non-null  int64
#  13  credit_score              1000000 non-null  int64
#  14  account_age_years         1000000 non-null  float64
#  15  account_balance           1000000 non-null  float64
#  16  transaction_amount        1000000 non-null  float64
#  17  num_prev_transactions     1000000 non-null  int64
#  18  transaction_freq_monthly  1000000 non-null  int64
#  19  distance_from_home_km     1000000 non-null  float64
#  20  time_since_last_txn_hrs   1000000 non-null  float64
#  21  is_international          1000000 non-null  int64
#  22  failed_attempts           1000000 non-null  int64
#  23  pin_changed_recently      1000000 non-null  int64
#  24  is_fraud                  1000000 non-null  int64
#  25  fraud_type                55255 non-null    str
# dtypes: float64(5), int64(11), str(10)
# memory usage: 198.4 MB

# %%
df["transaction_date"] = pd.to_datetime(df["transaction_date"])

# %%
df["transaction_time"] = pd.to_datetime(df["transaction_time"], format="%H:%M:%S").dt.time

# %%
df.isnull().sum()
# Out:
# transaction_id                   0
# customer_id                      0
# transaction_date                 0
# transaction_time                 0
# hour_of_day                      0
# is_weekend                       0
# is_night_transaction             0
# country                          0
# city                             0
# merchant_category                0
# payment_method                   0
# device_type                      0
# customer_age                     0
# credit_score                     0
# account_age_years                0
# account_balance                  0
# transaction_amount               0
# num_prev_transactions            0
# transaction_freq_monthly         0
# distance_from_home_km            0
# time_since_last_txn_hrs          0
# is_international                 0
# failed_attempts                  0
# pin_changed_recently             0
# is_fraud                         0
# fraud_type                  944745
# dtype: int64

# %%
df.describe()
# Out:
#                  transaction_date     hour_of_day      is_weekend  \
# count                     1000000  1000000.000000  1000000.000000
# mean   2022-06-30 17:45:08.006399       11.496978        0.286022
# min           2020-01-01 00:00:00        0.000000        0.000000
# 25%           2021-04-01 00:00:00        5.000000        0.000000
# 50%           2022-07-01 00:00:00       11.000000        0.000000
# 75%           2023-09-30 00:00:00       18.000000        1.000000
# max           2024-12-30 00:00:00       23.000000        1.000000
# std                           NaN        6.923751        0.451900
#
#        is_night_transaction    customer_age    credit_score  \
# count        1000000.000000  1000000.000000  1000000.000000
# mean               0.375057       41.771678      679.028781
# min                0.000000       18.000000      300.000000
# 25%                0.000000       32.000000      625.000000
# 50%                0.000000       42.000000      680.000000
# 75%                1.000000       51.000000      734.000000
# max                1.000000       85.000000      850.000000
# std                0.484138       13.424588       78.828748
#
#        account_age_years  account_balance  transaction_amount  \
# count     1000000.000000    1000000.00000      1000000.000000
# mean            4.987911      16594.25442          204.724665
# min             0.100000        100.00000            1.000000
# 25%             1.400000       3609.01750           33.400000
# 50%             3.500000       8092.12000           73.120000
# 75%             6.900000      18225.02500          181.450000
# max            30.000000     500000.00000        46129.600000
# std             4.925949      28171.46068          459.567802
#
#        num_prev_transactions  transaction_freq_monthly  distance_from_home_km  \
# count         1000000.000000            1000000.000000         1000000.000000
# mean              149.996350                 19.999322              20.009890
# min                96.000000                  2.000000               0.000000
# 25%               142.000000                 17.000000               5.800000
# 50%               150.000000                 20.000000              13.900000
# 75%               158.000000                 23.000000              27.700000
# max               213.000000                 44.000000             292.100000
# std                12.244379                  4.474045              20.011427
#
#        time_since_last_txn_hrs  is_international  failed_attempts  \
# count           1000000.000000    1000000.000000   1000000.000000
# mean                 12.000945          0.149994         0.380072
# min                   0.000000          0.000000         0.000000
# 25%                   3.450000          0.000000         0.000000
# 50%                   8.320000          0.000000         0.000000
# 75%                  16.630000          0.000000         0.000000
# max                 154.200000          1.000000         5.000000
# std                  11.999904          0.357066         0.914603
#
#        pin_changed_recently        is_fraud
# count        1000000.000000  1000000.000000
# mean               0.080439        0.055255
# min                0.000000        0.000000
# 25%                0.000000        0.000000
# 50%                0.000000        0.000000
# 75%                0.000000        0.000000
# max                1.000000        1.000000
# std                0.271972        0.228477

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   transaction_id            1000000 non-null  str
#  1   customer_id               1000000 non-null  str
#  2   transaction_date          1000000 non-null  datetime64[us]
#  3   transaction_time          1000000 non-null  object
#  4   hour_of_day               1000000 non-null  int64
#  5   is_weekend                1000000 non-null  int64
#  6   is_night_transaction      1000000 non-null  int64
#  7   country                   1000000 non-null  str
#  8   city                      1000000 non-null  str
#  9   merchant_category         1000000 non-null  str
#  10  payment_method            1000000 non-null  str
#  11  device_type               1000000 non-null  str
#  12  customer_age              1000000 non-null  int64
#  13  credit_score              1000000 non-null  int64
#  14  account_age_years         1000000 non-null  float64
#  15  account_balance           1000000 non-null  float64
#  16  transaction_amount        1000000 non-null  float64
#  17  num_prev_transactions     1000000 non-null  int64
#  18  transaction_freq_monthly  1000000 non-null  int64
#  19  distance_from_home_km     1000000 non-null  float64
#  20  time_since_last_txn_hrs   1000000 non-null  float64
#  21  is_international          1000000 non-null  int64
#  22  failed_attempts           1000000 non-null  int64
#  23  pin_changed_recently      1000000 non-null  int64
#  24  is_fraud                  1000000 non-null  int64
#  25  fraud_type                55255 non-null    str
# dtypes: datetime64[us](1), float64(5), int64(11), object(1), str(8)
# memory usage: 198.4+ MB

# %%
df.columns
# Out:
# Index(['transaction_id', 'customer_id', 'transaction_date', 'transaction_time',
#        'hour_of_day', 'is_weekend', 'is_night_transaction', 'country', 'city',
#        'merchant_category', 'payment_method', 'device_type', 'customer_age',
#        'credit_score', 'account_age_years', 'account_balance',
#        'transaction_amount', 'num_prev_transactions',
#        'transaction_freq_monthly', 'distance_from_home_km',
#        'time_since_last_txn_hrs', 'is_international', 'failed_attempts',
#        'pin_changed_recently', 'is_fraud', 'fraud_type'],
#       dtype='str')

# %%
df.to_csv("bank_fraud_cleaned.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\OneDrive\\Desktop\\project-tutorials'
